# %%
import sys
#print(sys.executable)
#!{sys.executable} -m pip install librosa soundfile
#!{sys.executable} -m pip install librosa soundfile pandas seaborn matplotlib ipython
import librosa
import pandas as pd
import matplotlib as plt
import seaborn as sns
from glob import glob
import IPython.display as ipd

# %%
import librosa
import IPython.display as ipd

audio, sr = librosa.load("ASVspoof2019_LA_train/flac/LA_T_1000137.flac", sr=None)
ipd.Audio(audio, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-flac;base64,..." type="audio/x-flac" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Out:
# Total audio files: 25380
